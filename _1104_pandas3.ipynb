# %% [markdown]
# # Pandas 3

# %%
import pandas as pd
import numpy as np

# %%
top50 = pd.read_csv('data/top50.csv')
top50.tail()
# Out:
#     Unnamed: 0                                     Track.Name  \
# 45          46                                One Thing Right
# 46          47                                      Te Robar�
# 47          48                                        Happier
# 48          49                                  Call You Mine
# 49          50  Cross Me (feat. Chance the Rapper & PnB Rock)
#
#          Artist.Name    Genre  Beats.Per.Minute  Energy  Danceability  \
# 45        Marshmello  brostep                88      62            66
# 46         Nicky Jam    latin               176      75            67
# 47        Marshmello  brostep               100      79            69
# 48  The Chainsmokers      edm               104      70            59
# 49        Ed Sheeran      pop                95      79            75
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 45              -2        58        44      182               7             5
# ...

# %% [markdown]
# # .unique()

# %%
top50['Genre']
# Out:
# 0         canadian pop
# 1       reggaeton flow
# 2            dance pop
# 3                  pop
# 4              dfw rap
# 5                  pop
# 6           trap music
# 7                  pop
# 8          country rap
# 9           electropop
# 10           reggaeton
# 11           dance pop
# 12                 pop
# 13      panamanian pop
# 14    canadian hip hop
# 15           dance pop
# 16               latin
# 17             dfw rap
# 18    canadian hip hop
# 19         escape room
# 20           pop house
# 21         country rap
# 22      reggaeton flow
# 23               latin
# 24          electropop
# 25        canadian pop
# 26      australian pop
# 27    canadian hip hop
# 28               latin
# 29               latin
# 30                 edm
# 31           dance pop
# 32           reggaeton
# 33         atl hip hop
# 34           dance pop
# 35            big room
# 36      panamanian pop
# 37                 pop
# 38            boy band
# 39           dance pop
# ...

# %%
# Pamėginkime išrinkti unikalias reikšmes iš stulpelio 'Genre':
top50['Genre'].unique()
# Out:
# array(['canadian pop', 'reggaeton flow', 'dance pop', 'pop', 'dfw rap',
#        'trap music', 'country rap', 'electropop', 'reggaeton',
#        'panamanian pop', 'canadian hip hop', 'latin', 'escape room',
#        'pop house', 'australian pop', 'edm', 'atl hip hop', 'big room',
#        'boy band', 'r&b en espanol', 'brostep'], dtype=object)

# %% [markdown]
# # .unique()

# %%
# jeigu norime sužinoti, kiek jų yra, tiesiog naudojame len funkciją:
len(top50['Genre'].unique())
# Out:
# 21

# %%
# tą patį gausime, panaudoję pandas metodą .nunique():
top50['Genre'].nunique()
# Out:
# 21

# %% [markdown]
# # .value_counts()

# %%
# galime panaudoti metodą .value_counts():
top50['Genre'].value_counts()

# gavome sąrašą unikalių reikšmių, ir kiek jų yra lentelėje.
# Out:
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# reggaeton           2
# reggaeton flow      2
# panamanian pop      2
# canadian pop        2
# electropop          2
# country rap         2
# dfw rap             2
# brostep             2
# trap music          1
# escape room         1
# pop house           1
# australian pop      1
# atl hip hop         1
# big room            1
# boy band            1
# r&b en espanol      1
# Name: Genre, dtype: int64

# %% [markdown]
# # .apply()

# %%
# length lenteleje nurodyta sekundemis
top50['Length.'].sum()
# Out:
# 10048

# %% [markdown]
# su .apply() galime maudoti ir savo funkcijas. Parašykime funkciją, kuri iš duotų sekundžių skaičiaus išskirs minutes ir sekundes formatu mm:ss

# %%
def minutes_seconds(seconds):
    minutes = seconds // 60
    seconds = seconds % 60
    return f'{minutes}:{seconds:02d}' # :02d - tai reiskia minimum du skaitmenys, d-digit, 0-uzpildom, jei nera, 2-kiek skaiciu

# %%
print(minutes_seconds(3))
print(minutes_seconds(121))
# Out:
# 0:03
# 2:01

# %%
# pritaikykime šią funkciją stulpeliui 'Length.':
top50['Length.'].apply(minutes_seconds)
# Out:
# 0     3:11
# 1     5:02
# 2     3:06
# 3     3:18
# 4     2:55
# 5     3:40
# 6     2:11
# 7     3:22
# 8     2:37
# 9     3:14
# 10    4:11
# 11    3:05
# 12    3:02
# 13    4:48
# 14    3:25
# 15    4:21
# 16    4:03
# 17    2:38
# 18    2:41
# 19    2:53
# 20    2:33
# 21    1:55
# 22    5:09
# 23    4:26
# 24    3:15
# 25    3:11
# 26    3:30
# 27    3:33
# 28    3:13
# 29    3:42
# 30    3:30
# 31    2:59
# 32    2:56
# 33    3:20
# 34    3:44
# 35    2:44
# 36    3:46
# 37    2:42
# 38    3:01
# 39    3:19
# 40    3:48
# 41    2:51
# 42    3:36
# 43    3:18
# 44    2:42
# 45    3:02
# 46    3:22
# 47    3:34
# 48    3:38
# 49    3:26
# Name: Length., dtype: object

# %%
# Gavome seriją. Galime jos pagrindu jos pagrindu pakoreguoti senąjį arba sukurti naują stulpelį, pvz.: Prideda papildoma stulpeli Length.Pretty
top50['Length.Pretty'] = top50['Length.'].apply(minutes_seconds)
top50.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Se�orita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
top = top50

# %%
# pavertėme 'Energy' stulpelio įvertinimus iš šimtabalės į dešimtbalę sistemą.
top['Energy'].apply(lambda x: round(x/10)).head()
# Out:
# 0    6
# 1    8
# 2    8
# 3    6
# 4    6
# Name: Energy, dtype: int64

# %%
top['Length.'].apply(lambda seconds: f'{seconds // 60}:{(seconds % 60):02d}')
# Out:
# 0     3:11
# 1     5:02
# 2     3:06
# 3     3:18
# 4     2:55
# 5     3:40
# 6     2:11
# 7     3:22
# 8     2:37
# 9     3:14
# 10    4:11
# 11    3:05
# 12    3:02
# 13    4:48
# 14    3:25
# 15    4:21
# 16    4:03
# 17    2:38
# 18    2:41
# 19    2:53
# 20    2:33
# 21    1:55
# 22    5:09
# 23    4:26
# 24    3:15
# 25    3:11
# 26    3:30
# 27    3:33
# 28    3:13
# 29    3:42
# 30    3:30
# 31    2:59
# 32    2:56
# 33    3:20
# 34    3:44
# 35    2:44
# 36    3:46
# 37    2:42
# 38    3:01
# 39    3:19
# 40    3:48
# 41    2:51
# 42    3:36
# 43    3:18
# 44    2:42
# 45    3:02
# 46    3:22
# 47    3:34
# 48    3:38
# 49    3:26
# Name: Length., dtype: object

# %% [markdown]
# # Naudingos funkcijos

# %% [markdown]
# # .columns

# %%
# grąžina stulpelių sąrašą
top.columns
# Out:
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity',
#        'Length.Pretty'],
#       dtype='object')

# %% [markdown]
# # .index

# %%
# suteikia informaciją apie indeksą:
top.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %% [markdown]
# # .shape

# %%
# 50 irasu, 15 stulpeliu
# grąžina tuple su eilučių ir stulpelių skaičiumi
top.shape
# Out:
# (50, 15)

# %% [markdown]
# # .sort_values

# %%
# surūšiuoja eilutes pagal nurodytą stulpelį:
# top.sort_values('Track.Name').head()
# top.sort_values('Artist.Name').head()
# top.sort_values('Length.').head()
top.sort_values('Length.', ascending=False).head()
# Out:
#     Unnamed: 0                 Track.Name  Artist.Name           Genre  \
# 22          23       No Me Conoce - Remix  Jhay Cortez  reggaeton flow
# 1            2                      China     Anuel AA  reggaeton flow
# 13          14         Otro Trago - Remix         Sech  panamanian pop
# 23          24            Soltera - Remix        Lunay           latin
# 15          16  No Guidance (feat. Drake)  Chris Brown       dance pop
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 22                92      79            81              -4         9
# 1                105      81            79              -4         8
# 13               176      79            73              -2         6
# 23                92      78            80              -4        44
# 15                93      45            70              -7        16
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity Length.Pretty
# ...

# %% [markdown]
# # .isnull()

# %%
# grąžina lentelę su boolean reikšmėmis kur True reiškia NaN.
top.isnull().head()

# ši lentelė tvarkinga, todėl True reikšmių nesimato :)
# Out:
#    Unnamed: 0  Track.Name  Artist.Name  Genre  Beats.Per.Minute  Energy  \
# 0       False       False        False  False             False   False
# 1       False       False        False  False             False   False
# 2       False       False        False  False             False   False
# 3       False       False        False  False             False   False
# 4       False       False        False  False             False   False
#
#    Danceability  Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  \
# 0         False           False     False     False    False           False
# 1         False           False     False     False    False           False
# 2         False           False     False     False    False           False
# 3         False           False     False     False    False           False
# 4         False           False     False     False    False           False
#
#    Speechiness.  Popularity  Length.Pretty
# ...

# %%
top.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
#  14  Length.Pretty     50 non-null     object
# dtypes: int64(11), object(4)
# memory usage: 6.0+ KB

# %% [markdown]
# # Duomenų nuskaitymas / įrašymas

# %% [markdown]
# # CSV

# %% [markdown]
# norėdami įrašyti duomenis į csv failą, darome taip:

# %%
top.to_csv('data/top50nice.csv', index=False)

# %% [markdown]
# # XLS

# %%
top.to_excel('top50.xls', sheet_name='top50')
# Out:
# C:\Users\ingri\AppData\Local\Temp\ipykernel_16376\77536783.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   top.to_excel('top50.xls', sheet_name='top50')

# %%
duomenys_xls = pd.read_excel('data/top50.xls', sheet_name='top50')
duomenys_xls.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                       Track.Name    Artist.Name  \
# 0             0           1                         Se�orita   Shawn Mendes
# 1             1           2                            China       Anuel AA
# 2             2           3    boyfriend (with Social House)  Ariana Grande
# 3             3           4  Beautiful People (feat. Khalid)     Ed Sheeran
# 4             4           5      Goodbyes (Feat. Young Thug)    Post Malone
#
#             Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# 0    canadian pop               117      55            76              -6
# 1  reggaeton flow               105      81            79              -4
# 2       dance pop               190      80            40              -4
# 3             pop                93      65            64              -8
# 4         dfw rap               150      65            58              -4
#
# ...

# %% [markdown]
# # HTML

# %%
top.to_html('data/top50.html')

# %%
duomenys_html = pd.read_html('https://lt.wikipedia.org/wiki/Vilniaus_miesto_savivaldyb%C4%97')
duomenys_html
# Out:
# [   Vilniaus miesto savivaldybė Vilniaus miesto savivaldybė.1
#  0                          NaN                           NaN
#  1                          NaN                           NaN
#  2                          NaN                           NaN
#  3                          NaN                           NaN
#  4                          NaN                           NaN
#  5                          NaN                           NaN
#  6                     Valstybė                       Lietuva
#  7                    Apskritis            Vilniaus apskritis
#  8      Administracinis centras                       Vilnius
#  9           Seniūnijų skaičius                            21
#  10                Įkūrimo data                       1995 m.
#  11                       Meras    Remigijus Šimašius (2019–)
#  12                         NaN                           NaN
#  13                   Gyventojų                    556 490[1]
# ...

# %%
for duomuo in duomenys_html:
    print(type(duomuo))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
duomenys_html[0]
# Out:
#    Vilniaus miesto savivaldybė Vilniaus miesto savivaldybė.1
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# 5                          NaN                           NaN
# 6                     Valstybė                       Lietuva
# 7                    Apskritis            Vilniaus apskritis
# 8      Administracinis centras                       Vilnius
# 9           Seniūnijų skaičius                            21
# 10                Įkūrimo data                       1995 m.
# 11                       Meras    Remigijus Šimašius (2019–)
# 12                         NaN                           NaN
# 13                   Gyventojų                    556 490[1]
# ...

# %%
duomenys_html[1]
# Out:
#                                                     0  \
# 0   Ž • A • RVilniaus miesto savivaldybės saugomos...
# 1   Ž • A • RVilniaus miesto savivaldybės saugomos...
# 2                                                 NaN
# 3                             Valstybiniai rezervatai
# 4                                                 NaN
# 5                                  Regioniniai parkai
# 6                                                 NaN
# 7                            Valstybiniai draustiniai
# 8                                                 NaN
# 9                            Savivaldybės draustiniai
# 10                                                NaN
# 11                                   Gamtos paminklai
# 12                                                NaN
# 13               Valstybiniai gamtos paveldo objektai
# 14                                                NaN
# 15               Savivaldybės gamtos paveldo objektai
#
# ...

# %%
duomenys_html[6]
# Out:
#    Savivaldybės istorija                            \
#                    Metai Plotas, km² Gyventojų sk.
# 0                1942 m.         NaN       146 300
# 1                1949 m.       139.0           NaN
# 2                1957 m.         NaN           NaN
# 3                1959 m.       142.0       230 769
# 4                1967 m.       153.0       316 400
# 5                1970 m.       265.0       372 100
# 6                1972 m.       262.0           NaN
# 7                1976 m.       263.0       445 900
# 8                1979 m.         NaN       475 825
# 9                1988 m.       287.0       577 000
# 10               1989 m.       287.0       576 747
# 11               1999 m.       401.0       588 400
# 12    2001 m. (Išsamiau)       401.0       553 904
#
#                                             \
#                               Suskirstymas
# 0                                      NaN
# 1   5 miesto rajonai (11 miesto apylinkių)
# ...

# %% [markdown]
# # SQL

# %%
istorija = duomenys_html[6]
istorija
# Out:
#    Savivaldybės istorija                            \
#                    Metai Plotas, km² Gyventojų sk.
# 0                1942 m.         NaN       146 300
# 1                1949 m.       139.0           NaN
# 2                1957 m.         NaN           NaN
# 3                1959 m.       142.0       230 769
# 4                1967 m.       153.0       316 400
# 5                1970 m.       265.0       372 100
# 6                1972 m.       262.0           NaN
# 7                1976 m.       263.0       445 900
# 8                1979 m.         NaN       475 825
# 9                1988 m.       287.0       577 000
# 10               1989 m.       287.0       576 747
# 11               1999 m.       401.0       588 400
# 12    2001 m. (Išsamiau)       401.0       553 904
#
#                                             \
#                               Suskirstymas
# 0                                      NaN
# 1   5 miesto rajonai (11 miesto apylinkių)
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///data/demo_istorija.db')
engine
# Out:
# Engine(sqlite:///data/demo_istorija.db)

# %%
istorija.to_sql('istorija', con=engine, index=False)
# Out:
# 13

# %%
duomenys_sql = pd.read_sql('istorija', con=engine)
duomenys_sql
# Out:
#    ('Savivaldybės istorija', 'Metai')  \
# 0                             1942 m.
# 1                             1949 m.
# 2                             1957 m.
# 3                             1959 m.
# 4                             1967 m.
# 5                             1970 m.
# 6                             1972 m.
# 7                             1976 m.
# 8                             1979 m.
# 9                             1988 m.
# 10                            1989 m.
# 11                            1999 m.
# 12                 2001 m. (Išsamiau)
#
#     ('Savivaldybės istorija', 'Plotas, km²')  \
# 0                                        NaN
# 1                                      139.0
# 2                                        NaN
# 3                                      142.0
# 4                                      153.0
# 5                                      265.0
# 6                                      262.0
# 7                                      263.0
# ...
